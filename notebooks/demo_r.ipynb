# %%
library(tigris)
library(sf)
library(mapview)
library(ggplot2)
# Out:
# To enable caching of data, set `options(tigris_use_cache = TRUE)`
# in your R script or .Rprofile.
#
# Linking to GEOS 3.13.0, GDAL 3.10.0, PROJ 9.5.0; sf_use_s2() is TRUE

# %%
ca_counties <- counties("CA")
# Out:
# Retrieving data for the year 2022
#   |======================================================================| 100%

# %%
plot(ca_counties$geometry)
# Out:
# plot without title

# %%
ggplot(ca_counties) + 
  geom_sf()
# Out:
# plot without title

# %%
#| label: fig-statemap
mapview(ca_counties)

# %%
m

# %%
mapview(breweries)

# %%
ca_counties
# Out:
# ERROR while rich displaying an object: Error in loadNamespace(x): there is no package called ‘geojsonio’
#
# Traceback:
# 1. sapply(x, f, simplify = simplify)
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. doTryCatch(return(expr), name, parentenv, handler)
# 8. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
# ...

# %%
library(knitr)

# %%
kable(head(ca_counties['NAME']))
# Out:
# |    |NAME          |geometry                       |
# |:---|:-------------|:------------------------------|
# |9   |Sierra        |MULTIPOLYGON (((-120.5559 3... |
# |325 |Sacramento    |MULTIPOLYGON (((-121.4399 3... |
# |329 |Santa Barbara |MULTIPOLYGON (((-120.5823 3... |
# |346 |Calaveras     |MULTIPOLYGON (((-120.6318 3... |
# |394 |Ventura       |MULTIPOLYGON (((-119.6361 3... |
# |397 |Los Angeles   |MULTIPOLYGON (((-118.6782 3... |
